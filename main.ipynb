# %% [markdown]
# # Buổi 1:
#
#
# ## Bài 1:
# **Main idea**: Nhập giá trị bán kính và sủ dụng công thức để tính ra diện tích pi*r^2
#
# **Mã giả**:
#
#         nhập r
#         tính s qua pi*r^2
#
#
# **Output**
#
#         Nhap ban kinh hinh tron:
#         5
#         Dien tich hinh tron la: + 78.5
#         Chu vi P = 31.4

# %%
# !type Buoi1\Bai1\HinhTron.cs
# Out:
# using System;
# namespace Bai1;
# class HinhTron
# {
#     static void Main(String[] args)
#     {
#         Console.WriteLine("Nhap ban kinh hinh tron:");
#         double r = double.Parse(Console.ReadLine());
#         Console.WriteLine($"Dien tich hinh tron la: {Math.PI * r * r:F1}");
#         Console.WriteLine($"Chu vi P = {2*Math.PI*r:F1}");
#
#     }
# }

# %% [markdown]
# ## Bài 2:
#
# **Main idea**: Viết ba chuỗi ...
#
# **Mã giả**:
#
#         In 3 chuỗi ....
#
# **Output**:
#
#     Truong: Dai Hoc HUFILT
#     Khoa:CNTT
#     Ho Ten
# **Code**:

# %%
# !type Buoi1\Bai2\inNhan.cs
# Out:
# using System;
# namespace Bai2
# {
#     class inNhan
#     { static void Main(string[] args)
#     {
#         Console.WriteLine("Truong: Dai Hoc HUFILT");
#         Console.WriteLine("Khoa:CNTT");
#         Console.WriteLine("Ho Ten");
#     }
# }
# }

# %% [markdown]
# ## Bài 3:
#
# **Main Idea**: Giờ * 3600, Phút * 60, + giây ra giây tổng
#
# **Mã giả**:
#
#     Giờ * 3600 , phút *60, + giây
# **Output**:
#     Nhap so gio:
#     1
#     Nhap so phut:
#     20
#     Nhap so giay:
#     30
#     Tong so giay cua 1:20:30 la 4830
#
# **Code**:

# %%
# !type Buoi1\Bai3\DoisangGiay.cs
# Out:
# using System;
# namespace Bai3
# {
#     class DoisangGiay
#     {
#         static void Main(string[] args)
#         {
#             Console.WriteLine(" Nhap so gio:");
#             int gio = int.Parse(Console.ReadLine());
#             Console.WriteLine(" Nhap so phut:");
#             int phut = int.Parse(Console.ReadLine());
#             Console.WriteLine(" Nhap so giay:");
#             int giay = int.Parse(Console.ReadLine());
#             int tmpgio = gio * 3600;
#             int tmpphut = phut * 60;
#             int tonggiay = tmpgio + tmpphut + giay;
#             Console.WriteLine("Tong so giay cua {0}:{1}:{2} la {3} ", gio, phut, giay, tonggiay);
#             Console.ReadLine();
#         }
#     }
# }

# %% [markdown]
# ## Bài 4:
# **Main idea**: Đổi ngược lại sang giờ giây phút
#
# **Mã giả**:
#
# Nhập giây
#
# chia lấy nguyên cho 3600
# lấy biến tạm lưu kq chia dư 3600
# chia lấy nguyên cho 60
# chia lấy dư cho 60
#
# **Output**:
#
# Nhap vao tong so giay: 4810
# 4810 ung voi thoi gian la: 1:20:10

# %%
# !type Buoi1\Bai4\doiSanggioPhutGiay.cs
# Out:
# using System;
#
# namespace Bai4;
# class doiSangGioPhutGiay
# {
#     static void Main(String[] agrs)
#     {
#         Console.Write("Nhap vao tong so giay: ");
#         int tong= int.Parse(Console.ReadLine());
#         int tmp=tong;
#         int gio= tmp/3600;
#         tmp= tmp%3600;
#         int phut=tmp/60;
#         int giay=(tmp%60);
#         Console.WriteLine("{0} ung voi thoi gian la: {1}:{2}:{3}",tong,gio,phut,giay);
#
#     }
#
# }

# %% [markdown]
# ## Bài 5:
#
# **Main idea**: Nhập a,b,c rồi tính
#
# **Mã giả**:
#
# Nhập 3 giá trị
#
# Tính diện tích qua Heron qua chu vi
#
# **Output**:
#
#     Nhap do dai canh a: 2
#     Nhap do dai canh b: 4
#     Nhap do dai canh c: 3
#     Dien tich tam giac bang : 8.44
#
# **Code**:

# %%
# !type Buoi1\Bai5\DienTichTamGiac.cs
# Out:
# using System;
# namespace Bai5;
# class DienTichTamGiac
# {
#     static void Main(String[] args)
#     {
#         Console.Write("Nhap do dai canh a: ");
#         double a=double.Parse(Console.ReadLine());
#         Console.Write("Nhap do dai canh b: ");
#         double b=double.Parse(Console.ReadLine());
#         Console.Write("Nhap do dai canh c: ");
#          double c=double.Parse(Console.ReadLine());
#          //ép kiểu p ra kết quả thập phân
#          double p=(double)(a+b+c)/2;
#          //tính kết quả diện tích tam giác
#          double S= (double)(p*(p-a)*(p-b)*(p-c));
#       //ép kết quả in ra chỉ giữ 2 số thập phân
#         Console.Write("Dien tich tam giac bang : "+ $"{ S:F2}");
#
#
#     }
# }

# %% [markdown]
# ## Bài 6:
#
# **Main idea**: Nhập a và số mũ và dùng math ...
#
# **Mã giả**:
#
#     Nhập a và số mũ
#     dùng math.pow
#
# **Output**:
#
#     Nhap so thuc a: 2
#     Nhap so mu n: 4
#     Ket qua 2^4 la : 16

# %%
# !type Buoi1\Bai6\TinhMu.cs
# Out:
# using System;
# namespace Bai6;
# class TinhMu
# {
#     static void Main(String[] args)
#     {
#         Console.Write("Nhap so thuc a: ");
#         double a=double.Parse(Console.ReadLine());
#         Console.Write("Nhap so mu n: ");
#         double n=double.Parse(Console.ReadLine());
#         //tính kết quả a mũ n
#         double c=Math.Pow(a,n);
#         //ép kết quả in ra chỉ giữ 2 số thập phân
#         Console.Write("Ket qua {0}^{1} la : {2}", a, n, c);
#     }
# }
